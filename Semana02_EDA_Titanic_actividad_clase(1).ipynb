# %% [markdown]
# # Análisis Exploratorio de Datos: Titanic
#
# En esta actividad usaremos la base de datos de pasajeros del Titanic para practicar **análisis exploratorio de datos (EDA)**.
#
# El objetivo no es hacer la mayor cantidad posible de gráficos, sino aprender a **usar los datos para responder preguntas**.
#
# ## Pregunta de investigación
#
# > **¿Qué características de los pasajeros estaban asociadas con la supervivencia en el Titanic?**

# %% [markdown]
# ## Librerías de visualización
# ### Matplotlib
#
# Matplotlib tiene dos métodos para crear una figura, uno directo y otro enfocado a objetos.
# Algunos links de interés:
#
# - Argumentos que reciben matplotlib: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html
# - Más opciones de gráficos en https://matplotlib.org/2.0.2/gallery.html
# - Para una lista de colores disponibles en Matplotlib, https://matplotlib.org/stable/gallery/color/named_colors.html
# - Explicación de plt y ax https://towardsdatascience.com/what-are-the-plt-and-ax-in-matplotlib-exactly-d2cf4bf164a9
#
#
# ### Seaborn
# Proporciona una interfaz de alto nivel para dibujar gráficos estadísticos atractivos e informativos. A diferencia de Matplotlib, ésta no viene por defecto en Pandas.
# Galería de gráficos: https://seaborn.pydata.org/examples/index.html
#
# Otro link útil para visualizaciones en Python: https://python-graph-gallery.com/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.set_style("white")

# %% [markdown]
# ## Carga de los datos
#
# Cada fila de la base de datos corresponde a **un pasajero**.
#
# Las principales características disponibles son:
#
# - `Survived`: supervivencia, 0 = no, 1 = sí
# - `Pclass`: clase del pasajero, 1 = primera, 2 = segunda, 3 = tercera
# - `Sex`: sexo
# - `Age`: edad
# - `SibSp`: número de hermanos/as o cónyuges a bordo
# - `Parch`: número de padres o hijos a bordo
# - `Ticket`: identificador del pasaje
# - `Fare`: tarifa pagada
# - `Cabin`: cabina
# - `Embarked`: puerto de embarque, C = Cherbourg, Q = Queenstown, S = Southampton

# %%
titanic = pd.read_csv("titanic_semana_02.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### **cuáles variables son numéricas y cuáles son categóricas?**

# %% [markdown]
# # Parte 1: Comprender la muestra
#
# ## ¿Quiénes eran los pasajeros del Titanic?
#
# Antes de estudiar la supervivencia, necesitamos comprender a quiénes representan los datos.
#
# Preguntas iniciales:
#
# - ¿Cuántos pasajeros hay?
# - ¿Qué características contiene la base de datos?
# - ¿Cómo se distribuyen por sexo y clase?
# - ¿Qué edades aparecen?
# - ¿Cuánto pagaron por sus pasajes?
# - ¿Viajaban solos o acompañados?
# - ¿Desde qué puerto embarcaron?
#
# Revise la estructura general de la tabla: dimensión, columnas, estadística básica, etc.

# %% [markdown]
# ### Ejemplo de gráfico: pasajeros por sexo
#
# Para una característica categórica podemos comenzar contando cuántos pasajeros pertenecen a cada grupo.

# %%
plt.figure(figsize=(6,4))

sns.countplot(data=titanic, x="Sex", color="gold")

plt.xlabel("Sexo")
plt.ylabel("Número de pasajeros")
plt.title("Pasajeros según sexo")

plt.show()

# %% [markdown]
# ### Ahora usted
#
# **1. Grafique la cantidad de pasajeros según `Pclass`.**
#
# - Qué clase contiene más pasajeros?
# - La muestra está balanceada entre las tres clases?

# %%
# Escriba aquí su código
plt.figure(figsize=(6,4))

sns.countplot(data=titanic, x="Pclass", color="gold")

plt.xlabel("Pclass")
plt.ylabel("Número de pasajeros")
plt.title("Pasajeros segun clase")

plt.show()

# %% [markdown]
# Qué clase contiene más pasajeros? La clase 3 es la clase que mas pasajeros presenta
# La muestra está balanceada entre las tres clases? no, ya que se preencia una mayor densidad de los pasajeron en una de las clases

# %% [markdown]
# **2. Explore la distribución de `Age` con un histograma.**
#
# Pruebe, por ejemplo, con 15, 30 y 50 bins.
#
# - ¿Qué edades son más frecuentes?
# - ¿La distribución parece simétrica?
# - ¿El número de bins cambia su interpretación?

# %%
# Escriba aquí su código
# sns.histplot(...)
# Escriba aquí su código
plt.figure(figsize=(6,4))

sns.histplot(data=titanic, x="Age", color="gold", bins=15)

plt.xlabel("Age")
plt.ylabel("Número de pasajeros")
plt.title("Pasajeros segun edad")

plt.show()

# %%
plt.figure(figsize=(6,4))

sns.histplot(data=titanic, x="Age", color="gold", bins=30)

plt.xlabel("Age")
plt.ylabel("Número de pasajeros")
plt.title("Pasajeros segun edad")

plt.show()

# %%
plt.figure(figsize=(6,4))

sns.histplot(data=titanic, x="Age", color="gold", bins=50)

plt.xlabel("Age")
plt.ylabel("Número de pasajeros")
plt.title("Pasajeros segun edad")

plt.show()

# %% [markdown]
# ¿Qué edades son más frecuentes? las edades en el rango entre 20 y 30 años
# ¿La distribución parece simétrica? si, ya que se aprecia que los datos se organizn a lo largo de un eje central
# ¿El número de bins cambia su interpretación? no cambia la interpretaion, pero de a poco deja de presenciarse la distribucion

# %% [markdown]
# **3. Explore la distribución de `Fare`.**
#
# Puede usar un histograma o un boxplot.
#
# - ¿La distribución es simétrica?
# - ¿Existen tarifas muy superiores al resto?
# - ¿Qué podría significar esto?

# %%
# Escriba aquí su código
plt.figure(figsize=(6,4))

sns.histplot(data=titanic, x="Fare", color="gold", bins=50)
plt.xlabel("Fare")
plt.ylabel("n de pasajeros")
plt.title("Pasajeros segun Fare")

plt.show()

plt.figure(figsize=(6,4))

sns.boxplot(data=titanic, x="Fare", color="gold")

plt.xlabel("Fare")
plt.ylabel("Número de pasajeros")
plt.title("Pasajeros segun Fare")

plt.show()

# %% [markdown]
# ¿La distribución es simétrica? no, porque los valores no estan distribuidos alrededor de un valor central, sino que se alejan cada vez mas
# ¿Existen tarifas muy superiores al resto? si, hay outlayer muy altos
# ¿Qué podría significar esto? que hay una distribucion de bienes injusta, por lo tanto debemos someter a la sociedad a un regimen totalitario y comunista

# %% [markdown]
# # Parte 2: Calidad de los datos
#
# ## ¿Qué información falta y por qué podría importar?
#
# Antes de interpretar cualquier patrón debemos revisar la calidad de los datos.
#
# Nos interesa detectar:
#
# - valores faltantes
# - características con mucha información incompleta
# - valores extremos o sospechosos
# - decisiones de limpieza que puedan cambiar nuestras conclusiones

# %%
datos_faltantes = titanic.isnull().sum()
datos_faltantes
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Ejemplo de gráfico: valores faltantes
#
# Podemos visualizar cuántos datos faltan en cada característica.

# %%
faltantes = datos_faltantes[datos_faltantes > 0]

plt.figure(figsize=(7,4))

sns.barplot(x=faltantes.index, y=faltantes.values, color='gold')

plt.xlabel("Característica")
plt.ylabel("Número de valores faltantes")
plt.title("Valores faltantes en la base de datos")

plt.show()

# %% [markdown]
# ### Ahora usted
#
# Observe especialmente `Age`, `Cabin` y `Embarked`.
#
# **1. Compare la media y la mediana de `Age`.**
#
# - Son similares?
# - Es la media una buena representación de una edad típica?

# %%
# Escriba aquí su código
import numpy as np
mediana = np.median(titanic["Age"])
media= np.mean(titanic["Age"])
sns.histplot(data=titanic, x="Age", color="gold", bins=50)
plt.xlabel("Age")
plt.ylabel("n de pasajeros")
plt.title("Pasajeros segun Age")
plt.axvline(media, linestyle ="--", color = "red")
plt.axvline(mediana, linestyle ="--", color = "blue")

# %% [markdown]
# **2. La edad tiene datos faltantes.**
#
# - Le parece razonable reemplazar todas las edades faltantes por la media?
# - Qué problema podría producir esa decisión en la distribución de edades?
# - Qué otra estrategia consideraría?

# %% [markdown]
# Le parece razonable reemplazar todas las edades faltantes por la media? No, ya que muchos pasajeros terminarian con la misma edad
# Qué problema podría producir esa decisión en la distribución de edades? el poblema que se podri generar en la de perder variabilidad en los valores originales
# Qué otra estrategia consideraría? quizas estimar la edad a partir de otras variables

# %% [markdown]
# **3. `Cabin` tiene una gran cantidad de valores faltantes.**
#
# - Intentaría rellenarlos?
# - Eliminaría la característica?
# - Podría el hecho de conocer o no la cabina contener información por sí mismo?
#
# No hay una única respuesta correcta: justifique su decisión.

# %% [markdown]
# Intentaría rellenarlos? si, ya que estar en una cabina u otra nos puede entregar informacion relevante
# Eliminaría la característica? no, ya que puede inferir otras caracteristicas a partir de ella
# Podría el hecho de conocer o no la cabina contener información por sí mismo? si, la ubicacion de la cabina puede entregar informacion de la probabilidad de que un pasajero sobreviva

# %% [markdown]
# **4. `Embarked` tiene pocos datos faltantes.**
#
# - Qué estrategia simple usaría en este caso?
# - Por qué el tratamiento puede ser distinto al de `Cabin`?

# %% [markdown]
# Qué estrategia simple usaría en este caso? los eliminaria
# Por qué el tratamiento puede ser distinto al de Cabin? oor que el puerto e el que embarcaron no representa una facilidad a la hora de la supervivencia

# %% [markdown]
# # Parte 3: Explorar relaciones entre características
#
# ## ¿Cómo se relacionan las características de los pasajeros?
#
# Después de estudiar las características individualmente, podemos comenzar a buscar estructura en los datos.
#
# Preguntas posibles:
#
# - La tarifa pagada está relacionada con la clase?
# - Las edades son similares en todas las clases?
# - Quiénes viajaban acompañados?
# - Hay características que contienen información parcialmente similar?

# %% [markdown]
# ### Ejemplo de gráfico: tarifa según clase
#
# Un boxplot permite comparar la distribución de una característica numérica entre distintos grupos.

# %%
plt.figure(figsize=(7,4))

sns.boxplot(data=titanic, x="Pclass", y="Fare", color='gold')

plt.xlabel("Clase")
plt.ylabel("Tarifa")
plt.title("Tarifa pagada según clase")

plt.show()

# %% [markdown]
# ### Preguntas
#
# - La tarifa parece estar relacionada con la clase?
# - Hay dispersión dentro de cada clase?
# - Existen valores extremos?
# - Diría que `Fare` y `Pclass` contienen exactamente la misma información?

# %% [markdown]
# La tarifa parece estar relacionada con la clase? si, bastante relacionada
# Hay dispersión dentro de cada clase? si, dentro de la misma clase existe dispercion
# Existen valores extremos? si, en especial en primera clase, hay valores que se alejan mucho de la media
# Diría que Fare y Pclass contienen exactamente la misma información? si, ya que ambos hacen referencia direnca al poder adquisitivo de cada individuo, dando una idea de su estrato socio-economico

# %% [markdown]
# ### Ahora usted
#
# **1. Compare la distribución de edad entre las tres clases.**
#
# Use un gráfico que permita comparar las distribuciones.
#
# - Los pasajeros tienen edades similares en todas las clases?
# - Qué diferencias observa?

# %%
# Escriba aquí su código
# sns.boxplot(...)
plt.figure(figsize=(7,4))

sns.boxplot(data=titanic, x="Pclass", y="Age", color='gold')

plt.xlabel("Clase")
plt.ylabel("Edad")
plt.title("Edad según clase")

plt.show()

# %% [markdown]
# Los pasajeros tienen edades similares en todas las clases? aunque tienen mucha desbiacion, se puede precenciar que a mayor clase la mediana sube
# Qué diferencias observa? edades mas altas ocupan con mas frecuencia la primera clase

# %% [markdown]
# **2. Las características `SibSp` y `Parch` contienen información sobre familiares a bordo.**
#
# Construya una nueva característica llamada `Familia`, que represente el número total de personas del grupo familiar incluyendo al propio pasajero:
#
# \[
# Familia = SibSp + Parch + 1
# \]

# %%
# Complete el código

titanic["Familia"] = titanic["SibSp"] + titanic["Parch"] + 1

# %% [markdown]
# **3. Explore la nueva característica `Familia`.**
#
# - La mayoría de los pasajeros viajaba sola o acompañada?
# - Hay grupos familiares muy grandes?
# - Cambiaría su interpretación si solo mirara `SibSp` o `Parch` por separado?

# %%
# Escriba aquí su código
plt.figure(figsize=(6,4))

sns.boxplot(data=titanic, x="Familia", color="gold")

plt.xlabel("Familia")
plt.ylabel("Número de pasajeros")
plt.title("Pasajeros según familia")

plt.show()

median = np.median(titanic["Familia"])
print(median)
# Out:
# 1.0

# %% [markdown]
# La mayoría de los pasajeros viajaba sola o acompañada? como la mediana cae en 1 podemos decir que la mayoria de pasajerson viajaba sola
# Hay grupos familiares muy grandes? si, hay outlayer muy grandes
# Cambiaría su interpretación si solo mirara SibSp o Parch por separado? si, ya que uno mostraba solo relaion pades, la otra relacion hermanos/conyuges, por lo tanto estariamos perdiendo informacion de quieres pertenecen a abmos grupos

# %% [markdown]
# # Parte 4: Investigar la supervivencia
#
# ## ¿Qué características estaban asociadas con la supervivencia?
#
# Ahora incorporaremos `Survived`, la variable que queremos comprender.
#
# Investigaremos si la supervivencia está asociada con características como:
#
# - sexo
# - clase
# - edad
# - tamaño del grupo familiar

# %% [markdown]
# ### Ejemplo de gráfico: supervivencia según sexo
#
# Como `Survived` toma valores 0 y 1, su promedio dentro de un grupo corresponde a la **fracción de pasajeros que sobrevivió**.
#
# `seaborn.barplot` calcula por defecto la media de la variable del eje vertical.

# %%
plt.figure(figsize=(6,4))

sns.barplot(data=titanic, x="Sex", y="Survived", errorbar=None, color='gold')

plt.xlabel("Sexo")
plt.ylabel("Fracción de supervivencia")
plt.title("Supervivencia según sexo")
plt.ylim(0,1)

plt.show()

# %% [markdown]
# ### Preguntas
#
# - La fracción de supervivencia es similar para hombres y mujeres? no, la fraccion de mujeres es mayor
# - Podemos concluir a partir de este gráfico por qué existe la diferencia? si, podemos concluir que una mujer tenia mas probabilidad de sobrevivir

# %% [markdown]
# ### Ahora usted
#
# **1. Explore la supervivencia según `Pclass`.**
#
# - Hay diferencias entre las tres clases?
# - Existe una tendencia?

# %%
# Escriba aquí su código
plt.figure(figsize=(6,4))

sns.barplot(data=titanic, x="Pclass", y="Survived", errorbar=None, color='gold')

plt.xlabel("clase")
plt.ylabel("Fracción de supervivencia")
plt.title("Supervivencia según clase")
plt.ylim(0,1)

plt.show()

# %% [markdown]
# -Hay diferencias entre las tres clases?
# -Existe una tendencia?

# %% [markdown]
# **2. Explore la supervivencia según edad.**
#
# Puede comparar las distribuciones de edad de quienes sobrevivieron y quienes no sobrevivieron.
#
# - La edad parece estar asociada con supervivencia?
# - Hay algún grupo de edad que llame particularmente su atención?

# %%
# Crear grupos de edad
titanic["GrupoEdad"] = pd.cut(
    titanic["Age"],
    bins=[0, 12, 18, 30, 50, 80],
    labels=["0-12", "12-18", "18-30", "30-50", "M"]
)

plt.figure(figsize=(6,4))

sns.barplot(
    data=titanic,
    x="GrupoEdad",
    y="Survived",
    errorbar=None,
    color="gold"
)

plt.xlabel("Edad")
plt.ylabel("Fracción de supervivencia")
plt.title("Supervivencia según edad")
plt.ylim(0,1)

plt.show()

# %% [markdown]
# **3. Explore la supervivencia según `Familia`.**
#
# - Viajar solo parece favorable o desfavorable? No, parece más favorable viajar en un grupo
# - La relación parece simple? Sí, se ve que para grupos de familia pequeños era más posible salvarse
# - Qué ocurre con los grupos familiares grandes? tienden a tener menos fracción de los que sobrevivieron, con la excepción de las familias con 7 integrantes, quizas esto relacionado a un bienestar económico

# %%
plt.figure(figsize=(8, 4))

sns.barplot(
    data=titanic,
    x="Familia",
    y="Survived",
    errorbar=None,
    color="gold"
)

plt.xlabel("Número de familiares")
plt.ylabel("Fracción de supervivencia")
plt.title("Supervivencia según número de familiares")
plt.ylim(0, 1)

plt.show()

# %% [markdown]
# # Parte 5: Agregar contexto
#
# ## ¿Cambia una relación cuando consideramos otra característica?
#
# Una relación global puede esconder comportamientos diferentes dentro de la muestra.
#
# Ya estudiamos por separado:
#
# - `Pclass` y supervivencia
# - `Sex` y supervivencia
#
# Ahora podemos preguntar:
#  **¿La relación entre clase y supervivencia es igual para hombres y mujeres?**
#
#
# Esta es una forma sencilla de análisis multivariado: consideramos varias características al mismo tiempo.

# %% [markdown]
# ### Ejemplo de gráfico: clase, sexo y supervivencia

# %%
plt.figure(figsize=(7,4))

sns.pointplot(data=titanic,
              x="Pclass",
              y="Survived",
              hue="Sex",
              palette="Set2",
              errorbar=None)

plt.xlabel("Clase")
plt.ylabel("Fracción de supervivencia")
plt.title("Supervivencia según clase y sexo")
plt.ylim(0,1)

plt.show()

# %% [markdown]
# ### Preguntas sobre el ejemplo
#
# - La relación entre clase y supervivencia es igual para hombres y mujeres?
#
# No. La relación es diferente según el sexo:
#
# - En las mujeres, la supervivencia es muy alta en primera y segunda clase, pero disminuye bastante en tercera clase.
# - En los hombres, la supervivencia es baja en todas las clases y disminuye desde primera hacia tercera clase
#
# - Qué información se perdía cuando mirábamos solamente `Pclass`?
#
# - Perdimos la información de si el `Sex` influía aparte de la Clase
#
# - Qué información se perdía cuando mirábamos solamente `Sex`?
# - Lo mismo con la clase, tenemos que ver si existe otro factor que favorece la supervivencia
#
# - Hay algún grupo particularmente favorecido o desfavorecido?
# - El grupo favorecido son de las mujeres de primera clase, mientras que el grupo más desfavorecido es el de hombres de tercera clase.

# %% [markdown]
# ### Ahora usted
#
# **1. Cree una característica `Persona` con tres categorías:**
#
# - `mujer`
# - `hombre`
# - `niño/a`
#
# Considere como niño/a a un pasajero menor de 16 años.

# %%
titanic["Persona"] = np.where(
    titanic["Age"] < 16,
    "niño/a",
    np.where(titanic["Sex"] == "female", "mujer", "hombre")
)
# Out:
# Persona
# hombre    537
# mujer     271
# niño/a     83
# Name: count, dtype: int64

# %% [markdown]
# **2. Explore la supervivencia según `Persona` y `Pclass`.**
#
# - Los niños presentan el mismo patrón que los adultos? Una parececida, niños de segunda y primera clase tenian mas posibildiades de sobnrevivir que de tercera.
# - La clase sigue siendo importante dentro de cada grupo? la primera
# - Qué combinación de características parece asociarse con la mayor supervivencia? parece ser niños de segunda clase, aunque tambien puede ser que sea laa clase donde mas nilos se encuentran, de igual manera, niños de clases mas altas tenian mas posibilidades de sobrevivir

# %%
# Escriba aquí su código
plt.figure(figsize=(8, 4))

sns.pointplot(
    data=titanic,
    x="Pclass",
    y="Survived",
    hue="Persona",
    errorbar=None
)

plt.xlabel("Clase")
plt.ylabel("Fracción de supervivencia")
plt.title("Supervivencia según persona y clase")
plt.ylim(0, 1)

plt.show()

# %% [markdown]
# **3. Elija una relación adicional para explorar incorporando una tercera característica.**
#
# Algunas ideas:
#
# - edad + sexo + supervivencia;
# - tamaño de familia + clase + supervivencia;
# - puerto de embarque + clase + supervivencia.
#
# No necesita crear una figura complicada. El objetivo es responder una pregunta concreta.
#
# **Escriba primero la pregunta que quiere investigar y luego construya el gráfico.**

# %%
# Pregunta: como cambia la supervivencia según el tamaño de la familia y la clase en la que viajaba el pasajero?


titanic["GrupoFamilia"] = pd.cut(
    titanic["Familia"],
    bins=[0, 1, 4, 7, 20],
    labels=["Solo", "Pequeña (2-4)", "Mediana (5-7)", "Grande (8+)"],
    include_lowest=True
)




plt.figure(figsize=(8, 4))

sns.pointplot(
    data=titanic,
    x="GrupoFamilia",
    y="Survived",
    hue="Pclass",
errorbar=None)

plt.xlabel("Tamaño de familia")
plt.ylabel("Fracción de supervivencia")
plt.title("Supervivencia según tamaño de familia y clase")
plt.ylim(0, 1)

plt.show()

# %% [markdown]
# # Parte 6: Conclusión
#
# ## ¿Qué podemos concluir?
#
# El EDA no termina cuando encontramos diferencias entre grupos.
#
# Queremos distinguir entre:
#
# ### Observación
# Algo que vemos directamente en los datos.
#
# ### Interpretación
# Cómo describimos ese patrón.
#
# ### Hipótesis
# Una explicación posible que debería ser evaluada con más información.
#
# Por ejemplo:
#
# > **Observación:** las mujeres presentan una mayor fracción de supervivencia que los hombres.
#
# - **Podemos concluir, solo a partir de esta base de datos, que durante la evacuación se dio prioridad a mujeres y niños?** No, porque los datos muestran una asociacion, no podemos dar una causa de estos efectos solo observando los datos
# - **Qué información adicional necesitaríamos para evaluar esa hipótesis?** un dato muy util seria la ubicacion de los pasajeros a la hora del accidente
# - **Qué otras explicaciones podrían producir el mismo patrón de supervivencia?** que tanto sexo como clase estuvieran relacionados, dando una preferencia hacia ciertos valores

# %% [markdown]
# ## Síntesis del análisis
#
# Revise todas las figuras construidas y responda:
#
# ### 1. Quiénes eran los pasajeros del Titanic?
#
# Describa brevemente la muestra considerando, al menos:
#
# - sexo
# - clase
# - edad
# - tamaño de familia.
#
# en la muestra habian principalmente hombres y muchos pasajeros viajaban en tercera clase. la mayoria eran adultos pero también había niños, habían personas que viajaban solas y otras acompañadas, principalmente familias pequeñas.
#
#
# ### 2. Qué características estaban asociadas con la supervivencia?
#
# Considere:
#
# - sexo
# - clase
# - edad
# - viajar solo o acompañado.
#
# el dato del sexo era importante, las mujeres sobrevivieron mucho más que los hombres. La clase también influyó, con mayor supervivencia en primera clase. Tambien se vio que niños sovrevivieron mas que los adultos.
#
# ### 3. Qué relaciones cambiaron al considerar varias características al mismo tiempo?
#
# Use como ejemplo al menos uno de los análisis multivariados realizados.
#
# Cuando vimos clase y sexo al mismo tiempo vimos que las mujeres destacaron por sobre los hombres en cada una al respecto de supervivencia.
#
# ### 4. Encontró características que contienen información relacionada?
#
# Explique al menos un caso.
#
# Si, un caso claro es el de en que clase pertenecen con la tarifa pagada, ya que personas de primera clase eran los que maypres tarifas pagaron
#
#
# ### 5. Qué resultado le pareció más inesperado?
#
# Proponga una posible explicación, dejando claro qué parte corresponde a una observación y qué parte corresponde a una hipótesis.
#
# que miesntras mas grande la familia no necesariamente era un indicador de mayor probabilidad de salvarse, por que familias numerosas tendian a tener menos probabilidad de sobrevivir, aunque una explicacion seria que para familais muy numerosas seria dificil organizarse

# %% [markdown]
# # Conclusión final
#
# ## ¿Cuál es el perfil del pasajero típico que sobrevivió?
#
# A partir de **sus propios resultados**, escriba una conclusión breve que caracterice al pasajero con mayor probabilidad de haber sobrevivido en esta muestra.
#
# Considere, cuando corresponda:
#
# - sexo
# - edad
# - clase
# - tamaño del grupo familiar
# - otras características que hayan resultado relevantes
#
# Su respuesta debe estar respaldada por las figuras que construyó.

# %% [markdown]
# ### Escriba aquí su conclusión
#
# **El pasajero típico que sobrevivió...**
#
# *(Complete con un párrafo breve basado en su análisis.)*

# %% [markdown]
# El tipo de pasajero que sobrevivió fue principalmente una mujer o un niñ@, y los que viajaban en primera o segunda clase también tenían más posibilidades. Además, la supervivencia tendía a ser mayor en personas que viajaban solas o en grupos familiares pequeños, mientras que los grupos familiares grandes presentaban menor supervivencia.
